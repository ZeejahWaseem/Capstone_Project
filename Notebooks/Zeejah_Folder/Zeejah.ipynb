# %%
import pandas as pd
import sqlite3
import numpy as np #importing numpy
from scipy import stats #importing Scipy
import seaborn as sns #importing seaborn
import matplotlib.pyplot as plt #importing matplotlib
from pandasql import sqldf #to querry databases directly with SQL syntax
# %matplotlib inline

# %%
df_gross = pd.read_csv("../../data/bom.movie_gross.csv.gz")

# %%
df_gross
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#      foreign_gross  year
# 0        652000000  2010
# 1        691300000  2010
# 2        664300000  2010
# 3        535700000  2010
# 4        513900000  2010
# ...            ...   ...
# 3382           NaN  2018
# 3383           NaN  2018
# 3384           NaN  2018
# 3385           NaN  2018
# 3386           NaN  2018
#
# [3387 rows x 5 columns]

# %%
df_tmdb = pd.read_csv("../../data/tmdb.movies.csv.gz")

# %%
df_tmdb
# Out:
#        Unnamed: 0            genre_ids      id original_language  \
# 0               0      [12, 14, 10751]   12444                en
# 1               1  [14, 12, 16, 10751]   10191                en
# 2               2        [12, 28, 878]   10138                en
# 3               3      [16, 35, 10751]     862                en
# 4               4        [28, 878, 12]   27205                en
# ...           ...                  ...     ...               ...
# 26512       26512             [27, 18]  488143                en
# 26513       26513             [18, 53]  485975                en
# 26514       26514         [14, 28, 12]  381231                en
# 26515       26515      [10751, 12, 28]  366854                en
# 26516       26516             [53, 27]  309885                en
#
#                                      original_title  popularity release_date  \
# 0      Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                          How to Train Your Dragon      28.734   2010-03-26
# 2                                        Iron Man 2      28.515   2010-05-07
# 3                                         Toy Story      28.005   1995-11-22
# 4                                         Inception      27.920   2010-07-16
# ...                                             ...         ...          ...
# 26512                         Laboratory Conditions       0.600   2018-10-13
# 26513                               _EXHIBIT_84xxx_       0.600   2018-05-01
# 26514                                  The Last One       0.600   2018-10-01
# 26515                                  Trailer Made       0.600   2018-06-22
# 26516                                    The Church       0.600   2018-10-05
#
#                                               title  vote_average  vote_count
# 0      Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                          How to Train Your Dragon           7.7        7610
# 2                                        Iron Man 2           6.8       12368
# 3                                         Toy Story           7.9       10174
# 4                                         Inception           8.3       22186
# ...                                             ...           ...         ...
# 26512                         Laboratory Conditions           0.0           1
# 26513                               _EXHIBIT_84xxx_           0.0           1
# 26514                                  The Last One           0.0           1
# 26515                                  Trailer Made           0.0           1
# 26516                                    The Church           0.0           1
#
# [26517 rows x 10 columns]

# %%
df_budget = pd.read_csv("../../data/tn.movie_budgets.csv.gz")

# %%
df_budget
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#      production_budget domestic_gross worldwide_gross
# 0         $425,000,000   $760,507,625  $2,776,345,279
# 1         $410,600,000   $241,063,875  $1,045,663,875
# 2         $350,000,000    $42,762,350    $149,762,350
# 3         $330,600,000   $459,005,868  $1,403,013,963
# 4         $317,000,000   $620,181,382  $1,316,721,747
# ...                ...            ...             ...
# 5777            $7,000             $0              $0
# 5778            $6,000        $48,482        $240,495
# 5779            $5,000         $1,338          $1,338
# 5780            $1,400             $0              $0
# 5781            $1,100       $181,041        $181,041
#
# [5782 rows x 6 columns]

# %%
df_info = pd.read_csv("../../data/rt.movie_info.tsv.gz", sep='\t')

# %%
df_info
# Out:
#         id                                           synopsis rating  \
# 0        1  This gritty, fast-paced, and innovative police...      R
# 1        3  New York City, not-too-distant-future: Eric Pa...      R
# 2        5  Illeana Douglas delivers a superb performance ...      R
# 3        6  Michael Douglas runs afoul of a treacherous su...      R
# 4        7                                                NaN     NR
# ...    ...                                                ...    ...
# 1555  1996  Forget terrorists or hijackers -- there's a ha...      R
# 1556  1997  The popular Saturday Night Live sketch was exp...     PG
# 1557  1998  Based on a novel by Richard Powell, when the l...      G
# 1558  1999  The Sandlot is a coming-of-age story about a g...     PG
# 1559  2000  Suspended from the force, Paris cop Hubert is ...      R
#
#                                                   genre            director  \
# 0                   Action and Adventure|Classics|Drama    William Friedkin
# 1                     Drama|Science Fiction and Fantasy    David Cronenberg
# 2                     Drama|Musical and Performing Arts      Allison Anders
# 3                            Drama|Mystery and Suspense      Barry Levinson
# 4                                         Drama|Romance      Rodney Bennett
# ...                                                 ...                 ...
# 1555   Action and Adventure|Horror|Mystery and Suspense                 NaN
# 1556                 Comedy|Science Fiction and Fantasy        Steve Barron
# 1557  Classics|Comedy|Drama|Musical and Performing Arts      Gordon Douglas
# 1558    Comedy|Drama|Kids and Family|Sports and Fitness  David Mickey Evans
# 1559  Action and Adventure|Art House and Internation...                 NaN
#
#                                                 writer  theater_date  \
# 0                                       Ernest Tidyman   Oct 9, 1971
# 1                         David Cronenberg|Don DeLillo  Aug 17, 2012
# 2                                       Allison Anders  Sep 13, 1996
# 3                      Paul Attanasio|Michael Crichton   Dec 9, 1994
# 4                                         Giles Cooper           NaN
# ...                                                ...           ...
# 1555                                               NaN  Aug 18, 2006
# 1556  Terry Turner|Tom Davis|Dan Aykroyd|Bonnie Turner  Jul 23, 1993
# 1557                                               NaN   Jan 1, 1962
# 1558                  David Mickey Evans|Robert Gunter   Apr 1, 1993
# 1559                                        Luc Besson  Sep 27, 2001
#
#           dvd_date currency  box_office      runtime             studio
# 0     Sep 25, 2001      NaN         NaN  104 minutes                NaN
# 1      Jan 1, 2013        $     600,000  108 minutes  Entertainment One
# 2     Apr 18, 2000      NaN         NaN  116 minutes                NaN
# 3     Aug 27, 1997      NaN         NaN  128 minutes                NaN
# 4              NaN      NaN         NaN  200 minutes                NaN
# ...            ...      ...         ...          ...                ...
# 1555   Jan 2, 2007        $  33,886,034  106 minutes    New Line Cinema
# 1556  Apr 17, 2001      NaN         NaN   88 minutes  Paramount Vantage
# 1557  May 11, 2004      NaN         NaN  111 minutes                NaN
# 1558  Jan 29, 2002      NaN         NaN  101 minutes                NaN
# 1559  Feb 11, 2003      NaN         NaN   94 minutes  Columbia Pictures
#
# [1560 rows x 12 columns]

# %%
df_info[df_info['director'].str.startswith('Ser', na = False)]
# Out:
#         id                                           synopsis rating  \
# 1179  1513  Along with Tarkovsky and Dovzhenko, Sergei Par...     NR
# 1216  1568  Jonathan Corbett (Lee Van Cleef) is one of the...      R
# 1352  1746  Director Sergei Paradjanov made a practice of ...     NR
#
#                                                   genre          director  \
# 1179          Art House and International|Drama|Romance  Sergei Parajanov
# 1216                       Action and Adventure|Western    Sergio Sollima
# 1352  Art House and International|Drama|Special Inte...  Sergei Parajanov
#
#                             writer  theater_date      dvd_date currency  \
# 1179                           NaN  Mar 16, 1967   Feb 5, 2008      NaN
# 1216  Sergio Sollima|Sergio Donati   Jan 1, 1966  Dec 10, 2013      NaN
# 1352   Sergei Parajanov|Sayat Nova   Oct 6, 1980   Mar 8, 2005      NaN
#
#      box_office     runtime studio
# 1179        NaN  99 minutes    NaN
# 1216        NaN  84 minutes    NaN
# 1352        NaN  90 minutes    NaN

# %%
df_reviews = pd.read_csv("../../data/rt.reviews.tsv.gz", sep='\t', engine = 'python')

# %%
df_reviews
# Out:
#          id                                             review rating   fresh  \
# 0         3  A distinctly gallows take on contemporary fina...    3/5   fresh
# 1         3  It's an allegory in search of a meaning that n...    NaN  rotten
# 2         3  ... life lived in a bubble in financial dealin...    NaN   fresh
# 3         3  Continuing along a line introduced in last yea...    NaN   fresh
# 4         3             ... a perverse twist on neorealism...     NaN   fresh
# ...     ...                                                ...    ...     ...
# 54427  2000  The real charm of this trifle is the deadpan c...    NaN   fresh
# 54428  2000                                                NaN    1/5  rotten
# 54429  2000                                                NaN    2/5  rotten
# 54430  2000                                                NaN  2.5/5  rotten
# 54431  2000                                                NaN    3/5   fresh
#
#                   critic  top_critic         publisher                date
# 0             PJ Nabarro           0   Patrick Nabarro   November 10, 2018
# 1         Annalee Newitz           0           io9.com        May 23, 2018
# 2           Sean Axmaker           0  Stream on Demand     January 4, 2018
# 3          Daniel Kasman           0              MUBI   November 16, 2017
# 4                    NaN           0      Cinema Scope    October 12, 2017
# ...                  ...         ...               ...                 ...
# 54427      Laura Sinagra           1     Village Voice  September 24, 2002
# 54428  Michael Szymanski           0        Zap2it.com  September 21, 2005
# 54429       Emanuel Levy           0   EmanuelLevy.Com       July 17, 2005
# 54430   Christopher Null           0    Filmcritic.com   September 7, 2003
# 54431    Nicolas Lacroix           0      Showbizz.net   November 12, 2002
#
# [54432 rows x 8 columns]

# %%
conn = sqlite3.connect('../../data/im.db')

# %%
df_db = pd.read_sql("""SELECT * FROM movie_ratings;""", conn)

# %%
df_db
# Out:
#          movie_id  averagerating  numvotes
# 0      tt10356526            8.3        31
# 1      tt10384606            8.9       559
# 2       tt1042974            6.4        20
# 3       tt1043726            4.2     50352
# 4       tt1060240            6.5        21
# ...           ...            ...       ...
# 73851   tt9805820            8.1        25
# 73852   tt9844256            7.5        24
# 73853   tt9851050            4.7        14
# 73854   tt9886934            7.0         5
# 73855   tt9894098            6.3       128
#
# [73856 rows x 3 columns]

# %%
basics_df = pd.read_sql("""SELECT DISTINCT * FROM movie_basics;""", conn)
basics_df.info() #loads basics table into dataframe and displays info
basics_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 6 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   movie_id         146144 non-null  object
#  1   primary_title    146144 non-null  object
#  2   original_title   146123 non-null  object
#  3   start_year       146144 non-null  int64
#  4   runtime_minutes  114405 non-null  float64
#  5   genres           140736 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 6.7+ MB
#     movie_id                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy

# %%
joined_tables_df = pd.read_sql("""SELECT *
FROM movie_basics
JOIN movie_ratings
    USING(movie_id)
WHERE averagerating >= 8
GROUP BY genres
ORDER BY averagerating DESC
;
""", conn)

# %%
joined_tables_df.head(25)
# Out:
#       movie_id                                      primary_title  \
# 0    tt7541970                                  From Shock to Awe
# 1    tt1740810                                    Love on a Leash
# 2   tt10146728                                        Foosballers
# 3    tt5963218                                      Aloko Udapadi
# 4    tt1791606  Some Called Them Baby Killers... We Call Them ...
# 5    tt4460258                                    Of Dogs and Men
# 6    tt4135932                                      Lost Conquest
# 7    tt5858514                            The Children of Genghis
# 8    tt8593814  The Boys Are Back - Bandstand: The Broadway Mu...
# 9    tt3856476                                           Sunakali
# 10   tt1700437                                        Silent Drum
# 11   tt5354160                                           Aynabaji
# 12   tt7053290                       Hugo: A Hidden Past Revealed
# 13   tt3328056                                     Mount Lawrence
# 14   tt5813916                                    The Mountain II
# 15   tt4335210                                   Road to Marakesh
# 16   tt6754546                               Continuamente amando
# 17   tt5903964                              The Long Count Teaser
# 18  tt10156610                              Ratne Price Sa Kosara
# 19   tt1684889                                             I Ride
# 20   tt6203844                       Anuktatop: the metamorphosis
# 21   tt2646540                              Estudiar en primavera
# 22   tt7516844                                  Roof Culture Asia
# 23   tt2033219                                   Rites of Passage
# 24   tt1651906                         Mzungu (n.) White-Wanderer
#
#                                        original_title  start_year  \
# 0                                   From Shock to Awe        2017
# 1                                     Love on a Leash        2010
# 2                                         Foosballers        2019
# 3                                       Aloko Udapadi        2017
# 4   Some Called Them Baby Killers... We Call Them ...        2010
# 5                                     Of Dogs and Men        2016
# 6                                       Lost Conquest        2015
# 7                                 Chingisiin huuhduud        2017
# 8   The Boys Are Back - Bandstand: The Broadway Mu...        2018
# 9                                            Sunakali        2017
# 10                                        Silent Drum        2010
# 11                                           Aynabaji        2016
# 12                       Hugo: A Hidden Past Revealed        2017
# 13                                     Mount Lawrence        2015
# 14                                             Dag II        2016
# 15                                   Road to Marakesh        2012
# 16                               Continuamente amando        2015
# 17                              The Long Count Teaser        2016
# 18                              Ratne Price Sa Kosara        2019
# 19                                             I Ride        2013
# 20                       Anuktatop: the metamorphosis        2016
# 21                              Estudiar en primavera        2014
# 22                                  Roof Culture Asia        2017
# 23                      Burning Man: Rites of Passage        2012
# 24                         Mzungu (n.) White-Wanderer        2010
#
#     runtime_minutes                         genres  averagerating  numvotes
# 0              87.0                Documentary,War            9.7         6
# 1              10.0     Documentary,Family,Romance            9.7        25
# 2               NaN       Comedy,Documentary,Sport            9.7        22
# 3             113.0                  Drama,History            9.5      6509
# 4              93.0          Documentary,Drama,War            9.4         5
# 5              89.0         Crime,Documentary,News            9.4        12
# 6              70.0     Comedy,Documentary,Fantasy            9.4         5
# 7             101.0               Adventure,Family            9.4       797
# 8             130.0                        Musical            9.3        50
# 9              59.0     Documentary,Family,Musical            9.3        19
# 10             71.0        Documentary,Drama,Music            9.3         6
# 11            147.0         Crime,Mystery,Thriller            9.3     18470
# 12             50.0  Adventure,Documentary,History            9.3         6
# 13             90.0   Adventure,Documentary,Family            9.3        47
# 14            135.0               Action,Drama,War            9.3    100568
# 15              NaN                            War            9.2         5
# 16            108.0                Mystery,Romance            9.2        76
# 17              NaN                  History,Sport            9.2         5
# 18            107.0        Documentary,History,War            9.2        29
# 19             82.0       Documentary,Family,Music            9.2         6
# 20            112.0     Documentary,Family,Fantasy            9.2         5
# 21             53.0      Documentary,Drama,Musical            9.2        17
# 22            113.0                Adventure,Sport            9.2        72
# 23             77.0  Adventure,Documentary,Western            9.2        73
# 24             80.0    Adventure,Documentary,Drama            9.2         9

# %%
joined_tables_df['genres'] = joined_tables_df['genres'].str.split(",")

# %%
genres_split_df = joined_tables_df.explode("genres")

# %%
genres_split_df # the seperation was loaded into this dataframe
# Out:
#       movie_id      primary_title     original_title  start_year  \
# 0    tt7541970  From Shock to Awe  From Shock to Awe        2017
# 0    tt7541970  From Shock to Awe  From Shock to Awe        2017
# 1    tt1740810    Love on a Leash    Love on a Leash        2010
# 1    tt1740810    Love on a Leash    Love on a Leash        2010
# 1    tt1740810    Love on a Leash    Love on a Leash        2010
# ..         ...                ...                ...         ...
# 458  tt3796898        Mousetrap 2        Mousetrap 2        2014
# 458  tt3796898        Mousetrap 2        Mousetrap 2        2014
# 459  tt1663202       The Revenant       The Revenant        2015
# 459  tt1663202       The Revenant       The Revenant        2015
# 459  tt1663202       The Revenant       The Revenant        2015
#
#      runtime_minutes       genres  averagerating  numvotes
# 0               87.0  Documentary            9.7         6
# 0               87.0          War            9.7         6
# 1               10.0  Documentary            9.7        25
# 1               10.0       Family            9.7        25
# 1               10.0      Romance            9.7        25
# ..               ...          ...            ...       ...
# 458             80.0    Adventure            8.0        12
# 458             80.0        Crime            8.0        12
# 459            156.0       Action            8.0    621193
# 459            156.0    Adventure            8.0    621193
# 459            156.0    Biography            8.0    621193
#
# [1224 rows x 8 columns]

# %%
genres_split_df['genres'].value_counts()
# Out:
# Drama          147
# Documentary    123
# Comedy         116
# Adventure       72
# Action          71
# Mystery         59
# Thriller        58
# Romance         54
# Fantasy         53
# Family          52
# Crime           50
# History         50
# Biography       49
# Animation       39
# Sci-Fi          38
# Music           36
# Musical         34
# Sport           30
# Horror          28
# War             27
# News            17
# Western         15
# Reality-TV       3
# Short            1
# Game-Show        1
# Name: genres, dtype: int64

# %%
genre_keys=genres_split_df['genres'].value_counts().keys()

# %%
genre_values=genres_split_df['genres'].value_counts().values

# %%
genre_values
# Out:
# array([147, 123, 116,  72,  71,  59,  58,  54,  53,  52,  50,  50,  49,
#         39,  38,  36,  34,  30,  28,  27,  17,  15,   3,   1,   1],
#       dtype=int64)

# %%
fig, ax = plt.subplots(figsize= (15,10) )
ax.bar(genre_keys[:10],genre_values[:10]) #the [:10] is to see the top ten genres in the dataset 
ax.set_title('Top Ten Genres with a Good Rating', fontsize= 20)
ax.set_xlabel('Genres',fontsize= 18)
ax.set_ylabel('Count',fontsize= 18)
ax.tick_params(axis='x', which='both', labelsize=14)
ax.tick_params(axis='y', which='both', labelsize=14)

# %%
fig, ax = plt.subplots(figsize= (13,13) )
ax.pie(genre_values, labels=genre_keys,autopct = lambda x:'{:2.0f}%'.format(x) if x>1 else '',textprops={'fontsize': 14}) #creates pie chart with the different genres
ax.tick_params(axis='x', which='both', labelsize=25)
ax.set_title('Percentages by Genre', fontsize= 20)
# Out:
# Text(0.5, 1.0, 'Percentages by Genre')

# %%
genres_split_df
# Out:
#       movie_id      primary_title     original_title  start_year  \
# 0    tt7541970  From Shock to Awe  From Shock to Awe        2017
# 0    tt7541970  From Shock to Awe  From Shock to Awe        2017
# 1    tt1740810    Love on a Leash    Love on a Leash        2010
# 1    tt1740810    Love on a Leash    Love on a Leash        2010
# 1    tt1740810    Love on a Leash    Love on a Leash        2010
# ..         ...                ...                ...         ...
# 458  tt3796898        Mousetrap 2        Mousetrap 2        2014
# 458  tt3796898        Mousetrap 2        Mousetrap 2        2014
# 459  tt1663202       The Revenant       The Revenant        2015
# 459  tt1663202       The Revenant       The Revenant        2015
# 459  tt1663202       The Revenant       The Revenant        2015
#
#      runtime_minutes       genres  averagerating  numvotes
# 0               87.0  Documentary            9.7         6
# 0               87.0          War            9.7         6
# 1               10.0  Documentary            9.7        25
# 1               10.0       Family            9.7        25
# 1               10.0      Romance            9.7        25
# ..               ...          ...            ...       ...
# 458             80.0    Adventure            8.0        12
# 458             80.0        Crime            8.0        12
# 459            156.0       Action            8.0    621193
# 459            156.0    Adventure            8.0    621193
# 459            156.0    Biography            8.0    621193
#
# [1224 rows x 8 columns]

# %%
genres_split_df.groupby('genres')['averagerating'].mean()
# Out:
# genres
# Action         8.314085
# Adventure      8.427778
# Animation      8.207692
# Biography      8.359184
# Comedy         8.404310
# Crime          8.374000
# Documentary    8.530894
# Drama          8.425170
# Family         8.507692
# Fantasy        8.373585
# Game-Show      9.000000
# History        8.422000
# Horror         8.332143
# Music          8.402778
# Musical        8.450000
# Mystery        8.354237
# News           8.500000
# Reality-TV     8.766667
# Romance        8.490741
# Sci-Fi         8.310526
# Short          8.800000
# Sport          8.483333
# Thriller       8.277586
# War            8.592593
# Western        8.386667
# Name: averagerating, dtype: float64

# %%
jt_df = pd.read_sql("""SELECT *
FROM movie_basics
JOIN movie_ratings
    USING(movie_id)
GROUP BY genres
ORDER BY averagerating DESC
;
""", conn)

# %%
jt_df
# Out:
#        movie_id          primary_title         original_title  start_year  \
# 0     tt1740810        Love on a Leash        Love on a Leash        2010
# 1    tt10146728            Foosballers            Foosballers        2019
# 2     tt4135932          Lost Conquest          Lost Conquest        2015
# 3     tt3856476               Sunakali               Sunakali        2017
# 4     tt5903964  The Long Count Teaser  The Long Count Teaser        2016
# ..          ...                    ...                    ...         ...
# 919   tt0249516             Foodfight!             Foodfight!        2012
# 920   tt0937353     The Devil's Flower        Tsvetok dyavola        2010
# 921   tt5161302          Eyal Hirrifah          Eyal Hirrifah        2015
# 922   tt1865374           Futures Past           Futures Past        2012
# 923   tt3437164           Maldito Amor           Maldito Amor        2014
#
#      runtime_minutes                      genres  averagerating  numvotes
# 0               10.0  Documentary,Family,Romance            9.7        25
# 1                NaN    Comedy,Documentary,Sport            9.7        22
# 2               70.0  Comedy,Documentary,Fantasy            9.4         5
# 3               59.0  Documentary,Family,Musical            9.3        19
# 4                NaN               History,Sport            9.2         5
# ..               ...                         ...            ...       ...
# 919             91.0     Action,Animation,Comedy            1.9      8248
# 920             90.0             Mystery,Romance            1.7       201
# 921            101.0        Comedy,Musical,Sport            1.4        28
# 922            120.0    Action,Biography,History            1.3        33
# 923            100.0       Comedy,History,Horror            1.1       168
#
# [924 rows x 8 columns]

# %%
jt_df['genres'] = jt_df['genres'].str.split(",")

# %%
jt_df=jt_df.explode('genres')

# %%
jt_df
# Out:
#        movie_id    primary_title   original_title  start_year  \
# 0     tt1740810  Love on a Leash  Love on a Leash        2010
# 0     tt1740810  Love on a Leash  Love on a Leash        2010
# 0     tt1740810  Love on a Leash  Love on a Leash        2010
# 1    tt10146728      Foosballers      Foosballers        2019
# 1    tt10146728      Foosballers      Foosballers        2019
# ..          ...              ...              ...         ...
# 922   tt1865374     Futures Past     Futures Past        2012
# 922   tt1865374     Futures Past     Futures Past        2012
# 923   tt3437164     Maldito Amor     Maldito Amor        2014
# 923   tt3437164     Maldito Amor     Maldito Amor        2014
# 923   tt3437164     Maldito Amor     Maldito Amor        2014
#
#      runtime_minutes       genres  averagerating  numvotes
# 0               10.0  Documentary            9.7        25
# 0               10.0       Family            9.7        25
# 0               10.0      Romance            9.7        25
# 1                NaN       Comedy            9.7        22
# 1                NaN  Documentary            9.7        22
# ..               ...          ...            ...       ...
# 922            120.0    Biography            1.3        33
# 922            120.0      History            1.3        33
# 923            100.0       Comedy            1.1       168
# 923            100.0      History            1.1       168
# 923            100.0       Horror            1.1       168
#
# [2537 rows x 8 columns]

# %%
rounded_rating = jt_df['averagerating'].round(2)

# %%
jt_df
# Out:
#        movie_id    primary_title   original_title  start_year  \
# 0     tt1740810  Love on a Leash  Love on a Leash        2010
# 0     tt1740810  Love on a Leash  Love on a Leash        2010
# 0     tt1740810  Love on a Leash  Love on a Leash        2010
# 1    tt10146728      Foosballers      Foosballers        2019
# 1    tt10146728      Foosballers      Foosballers        2019
# ..          ...              ...              ...         ...
# 922   tt1865374     Futures Past     Futures Past        2012
# 922   tt1865374     Futures Past     Futures Past        2012
# 923   tt3437164     Maldito Amor     Maldito Amor        2014
# 923   tt3437164     Maldito Amor     Maldito Amor        2014
# 923   tt3437164     Maldito Amor     Maldito Amor        2014
#
#      runtime_minutes       genres  averagerating  numvotes
# 0               10.0  Documentary            9.7        25
# 0               10.0       Family            9.7        25
# 0               10.0      Romance            9.7        25
# 1                NaN       Comedy            9.7        22
# 1                NaN  Documentary            9.7        22
# ..               ...          ...            ...       ...
# 922            120.0    Biography            1.3        33
# 922            120.0      History            1.3        33
# 923            100.0       Comedy            1.1       168
# 923            100.0      History            1.1       168
# 923            100.0       Horror            1.1       168
#
# [2537 rows x 8 columns]

# %%
avg_keys=sorted_avg_genres.keys()
avg_keys
avg_values=sorted_avg_genres.values
avg_values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-dc77bd3faa46> in <module>
# ----> 1 avg_keys=sorted_avg_genres.keys()
#       2 avg_keys
#       3 avg_values=sorted_avg_genres.values
#       4 avg_values
#
# NameError: name 'sorted_avg_genres' is not defined

# %%
y = avg_values[:10]

# %%
fig, ax = plt.subplots(figsize= (15,10) )
ax.bar(avg_keys[:10],avg_values[:10]) #the [:10] is to see the top ten genres in the dataset 
ax.set_title('Top Ten Genres', fontsize= 20)
ax.set_xlabel('Genres',fontsize= 18)
ax.set_ylabel('AVG Rating',fontsize= 18)
ax.tick_params(axis='x', which='both', labelsize=12)
ax.tick_params(axis='y', which='both', labelsize=12)

for i in range(len(avg_keys[:10])):
        plt.text(i, y[i], y[i], ha = 'center', Bbox = dict(facecolor = 'red', alpha =.8))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-c9d44845266f> in <module>
#       1 fig, ax = plt.subplots(figsize= (15,10) )
# ----> 2 ax.bar(avg_keys[:10],avg_values[:10]) #the [:10] is to see the top ten genres in the dataset
#       3 ax.set_title('Top Ten Genres', fontsize= 20)
#       4 ax.set_xlabel('Genres',fontsize= 18)
#       5 ax.set_ylabel('AVG Rating',fontsize= 18)
#
# NameError: name 'avg_keys' is not defined

# %%
q = """
SELECT *
FROM movie_basics
JOIN directors
    USING(movie_id)
JOIN Persons
    ON persons.person_id = directors.person_id
;
"""
df_directors = pd.read_sql(q, conn)
df_directors
# Out:
#          movie_id                    primary_title  \
# 0       tt0063540                        Sunghursh
# 1       tt0063540                        Sunghursh
# 2       tt0063540                        Sunghursh
# 3       tt0063540                        Sunghursh
# 4       tt0066787  One Day Before the Rainy Season
# ...           ...                              ...
# 291166  tt9916730                           6 Gunn
# 291167  tt9916754   Chico Albuquerque - Revelações
# 291168  tt9916754   Chico Albuquerque - Revelações
# 291169  tt9916754   Chico Albuquerque - Revelações
# 291170  tt9916754   Chico Albuquerque - Revelações
#
#                         original_title  start_year  runtime_minutes  \
# 0                            Sunghursh        2013            175.0
# 1                            Sunghursh        2013            175.0
# 2                            Sunghursh        2013            175.0
# 3                            Sunghursh        2013            175.0
# 4                      Ashad Ka Ek Din        2019            114.0
# ...                                ...         ...              ...
# 291166                          6 Gunn        2017            116.0
# 291167  Chico Albuquerque - Revelações        2013              NaN
# 291168  Chico Albuquerque - Revelações        2013              NaN
# 291169  Chico Albuquerque - Revelações        2013              NaN
# 291170  Chico Albuquerque - Revelações        2013              NaN
#
#                     genres   person_id   person_id            primary_name  \
# 0       Action,Crime,Drama   nm0712540   nm0712540     Harnam Singh Rawail
# 1       Action,Crime,Drama   nm0712540   nm0712540     Harnam Singh Rawail
# 2       Action,Crime,Drama   nm0712540   nm0712540     Harnam Singh Rawail
# 3       Action,Crime,Drama   nm0712540   nm0712540     Harnam Singh Rawail
# 4          Biography,Drama   nm0002411   nm0002411               Mani Kaul
# ...                    ...         ...         ...                     ...
# 291166                None  nm10538612  nm10538612            Kiran Gawade
# 291167         Documentary   nm8349149   nm8349149  Vinicius Augusto Bozzo
# 291168         Documentary   nm8349149   nm8349149  Vinicius Augusto Bozzo
# 291169         Documentary   nm9272490   nm9272490           Angela Gurgel
# 291170         Documentary   nm9272490   nm9272490           Angela Gurgel
#
#         birth_year  death_year        primary_profession
# 0           1921.0      2004.0  director,writer,producer
# 1           1921.0      2004.0  director,writer,producer
# 2           1921.0      2004.0  director,writer,producer
# 3           1921.0      2004.0  director,writer,producer
# 4           1944.0      2011.0     director,writer,actor
# ...            ...         ...                       ...
# 291166         NaN         NaN                      None
# 291167      1985.0         NaN    writer,editor,director
# 291168      1985.0         NaN    writer,editor,director
# 291169         NaN         NaN           director,writer
# 291170         NaN         NaN           director,writer
#
# [291171 rows x 12 columns]

# %%
Director = df_directors[df_directors['primary_name'].str.startswith('Sergey A.', na = False)]

# %%
Director
# Out:
#           movie_id                             primary_title  \
# 1544    tt10015432                 Forest of the Dead Sharks
# 2359    tt10096422                   Watch Movie Free Online
# 2706    tt10126462                                      Post
# 3196    tt10172204  Revenge in the Forest of the Dead Sharks
# 5851    tt10366896            All people disappeared forever
# ...            ...                                       ...
# 267827   tt8220556                                TeleviZion
# 269978   tt8359918                     Anthology of horror 8
# 283300   tt9209662                             Cursed forest
# 289745   tt9811598                                     Chaos
# 289837   tt9820678                       Moscow we will lose
#
#                                   original_title  start_year  runtime_minutes  \
# 1544                   Forest of the Dead Sharks        2019             50.0
# 2359                     Watch Movie Free Online        2019             45.0
# 2706                                        Post        2019             45.0
# 3196    Revenge in the Forest of the Dead Sharks        2019             50.0
# 5851              All people disappeared forever        2019             61.0
# ...                                          ...         ...              ...
# 267827                                TeleviZion        2018             60.0
# 269978                     Anthology of horror 8        2018             76.0
# 283300                             Cursed forest        2018             63.0
# 289745                                     Chaos        2019            126.0
# 289837                       Moscow we will lose        2019             51.0
#
#                          genres  person_id  person_id primary_name  \
# 1544       Action,Comedy,Horror  nm5954636  nm5954636    Sergey A.
# 2359    Action,Adventure,Comedy  nm5954636  nm5954636    Sergey A.
# 2706       Drama,Fantasy,Horror  nm5954636  nm5954636    Sergey A.
# 3196       Action,Comedy,Horror  nm5954636  nm5954636    Sergey A.
# 5851            Sci-Fi,Thriller  nm5954636  nm5954636    Sergey A.
# ...                         ...        ...        ...          ...
# 267827    Action,Comedy,Fantasy  nm5954636  nm5954636    Sergey A.
# 269978      Drama,Horror,Sci-Fi  nm5954636  nm5954636    Sergey A.
# 283300          Horror,Thriller  nm5954636  nm5954636    Sergey A.
# 289745                    Drama  nm5954636  nm5954636    Sergey A.
# 289837              Documentary  nm5954636  nm5954636    Sergey A.
#
#         birth_year  death_year               primary_profession
# 1544        1996.0         NaN  writer,producer,cinematographer
# 2359        1996.0         NaN  writer,producer,cinematographer
# 2706        1996.0         NaN  writer,producer,cinematographer
# 3196        1996.0         NaN  writer,producer,cinematographer
# 5851        1996.0         NaN  writer,producer,cinematographer
# ...            ...         ...                              ...
# 267827      1996.0         NaN  writer,producer,cinematographer
# 269978      1996.0         NaN  writer,producer,cinematographer
# 283300      1996.0         NaN  writer,producer,cinematographer
# 289745      1996.0         NaN  writer,producer,cinematographer
# 289837      1996.0         NaN  writer,producer,cinematographer
#
# [81 rows x 12 columns]

# %%
Director['genres'].str.contains('Documentary').sum()
# Out:
# 2

# %%
q = """
SELECT *
FROM persons
JOIN directors 
    USING(person_id)
WHERE primary_name == 'Sergey A.'
;
"""
df_personid = pd.read_sql(q, conn)
df_personid
# Out:
#     person_id primary_name  birth_year death_year  \
# 0   nm5954636    Sergey A.      1996.0       None
# 1   nm5954636    Sergey A.      1996.0       None
# 2   nm5954636    Sergey A.      1996.0       None
# 3   nm5954636    Sergey A.      1996.0       None
# 4   nm5954636    Sergey A.      1996.0       None
# ..        ...          ...         ...        ...
# 76  nm5954636    Sergey A.      1996.0       None
# 77  nm5954636    Sergey A.      1996.0       None
# 78  nm5954636    Sergey A.      1996.0       None
# 79  nm5954636    Sergey A.      1996.0       None
# 80  nm5954636    Sergey A.      1996.0       None
#
#                  primary_profession    movie_id
# 0   writer,producer,cinematographer  tt10015432
# 1   writer,producer,cinematographer  tt10096422
# 2   writer,producer,cinematographer  tt10126462
# 3   writer,producer,cinematographer  tt10172204
# 4   writer,producer,cinematographer  tt10366896
# ..                              ...         ...
# 76  writer,producer,cinematographer   tt8220556
# 77  writer,producer,cinematographer   tt8359918
# 78  writer,producer,cinematographer   tt9209662
# 79  writer,producer,cinematographer   tt9811598
# 80  writer,producer,cinematographer   tt9820678
#
# [81 rows x 6 columns]

# %%
q = """
SELECT *
FROM df_personid
WHERE primary_name == 'Sergey A.'
;
"""
pd.read_sql(q, conn)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\AppData\Local\anaconda3\envs\learn-env\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1680         try:
# -> 1681             cur.execute(*args, **kwargs)
#    1682             return cur
#
# OperationalError: no such table: df_personid
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-79-7b8f864ee0ce> in <module>
#       5 ;
#       6 """
# ----> 7 pd.read_sql(q, conn)
#
# ~\AppData\Local\anaconda3\envs\learn-env\lib\site-packages\pandas\io\sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     481
#     482     if isinstance(pandas_sql, SQLiteDatabase):
# --> 483         return pandas_sql.read_query(
#     484             sql,
#     485             index_col=index_col,
#
# ~\AppData\Local\anaconda3\envs\learn-env\lib\site-packages\pandas\io\sql.py in read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize)
#    1725
#    1726         args = _convert_params(sql, params)
# -> 1727         cursor = self.execute(*args)
#    1728         columns = [col_desc[0] for col_desc in cursor.description]
#    1729
#
# ~\AppData\Local\anaconda3\envs\learn-env\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1691
#    1692             ex = DatabaseError(f"Execution failed on sql '{args[0]}': {exc}")
# -> 1693             raise ex from exc
#    1694
#    1695     @staticmethod
#
# DatabaseError: Execution failed on sql '
# SELECT *
# FROM df_personid
# WHERE primary_name == 'Sergey A.'
# ;
# ': no such table: df_personid
